# %%
from IPython.display import Javascript

# %% [markdown]
# # Week 1 Tasks - Revision
# This week is a revision week.  Complete the exercises below

# %% [markdown]
# ## Task 1:
# Complete the functions below.

# %%
# adds two numbers and returns the result as a  number
def add_two_nums(a, b):
    pass

# returns the square of a number.
# note: zero squared is equal to 1
def power_of_two(a):
    pass

# returns the result of x to the power of y, must use a loop of recursion.
def power(x, y):
    pass

# returns the factorial of a number, must use a loop or recursion.  n must be a positive integer.
# if n is less than 0, return -1
# factorial of 0 is 1
def factorial(n):
    pass

# returns the sum of all numbers in an array.  Must use a loop or recursion.
# if the array is empty, return "error"
def add_nums_array(arr):
    pass

# returns the first element of an array. Must use a loop or recursion.
# return None if empty
def first_element(arr):
    pass

# returns the last element of an array.  Must use a loop or recursion.
# return None if empty
def last_element(arr):
    pass

# returns the number of elements in an array.  Must use a loop or recursion.
def num_elements(arr):
    pass

# returns two strings concatenated together.
def concat_strings(str1, str2):
    pass

# returns the number of characters in a string.  Must use a loop or recursion.
def num_chars(str1):
    pass

# returns string with the first letter capitalized.
def capitalize_first_letter(str1):
    pass

# returns a decimal to the nearest whole number.
def round_decimal(num):
    pass

Javascript("Jupyter.notebook.execute_cells([14])")

# %% [markdown]
# # Bonus Tasks:  Stretch yourself a little and have a go at the below

# %%
# returns the sum of all even numbers in an array.  Must use a loop or recursion.
def add_even_nums(arr):
    pass

# returns the sum of all odd numbers in an array.  Must use a loop or recursion.
def add_odd_nums(arr):
    pass

# returns the string in reverse.  Must use a loop or recursion.
def reverse_string(str1):
    pass

# returns whether string is a palindrome.  Must use a loop or recursion.
# a palindrome is a word that is the same forwards and backwards.
def is_palindrome(str1):
    pass

# %%
# task tests DO NOT MODIFY
import unittest

class Task1_test(unittest.TestCase):
    def test01_add_two_nums(self):
        self.assertEqual(add_two_nums(1, 2), 3)
        self.assertEqual(add_two_nums(-1, 1),0)
        self.assertEqual(add_two_nums(0, 0), 0)
        self.assertEqual(add_two_nums(100, 200), 300)
        self.assertEqual(add_two_nums(-1000, -2000), -3000)

    def test02_power_of_two(self):
        self.assertEqual(power_of_two(0), 1)
        self.assertEqual(power_of_two(1), 1)
        self.assertEqual(power_of_two(2), 4)
        self.assertEqual(power_of_two(3), 9)

    def test03_power(self):
        self.assertEqual(power(2, 0), 1)
        self.assertEqual(power(2, 1), 2)
        self.assertEqual(power(2, 2), 4)
        self.assertEqual(power(2, 3), 8)
        self.assertEqual(power(3, 2), 9)

    def test04_factorial(self):
        self.assertEqual(factorial(0), 1)
        self.assertEqual(factorial(1), 1)
        self.assertEqual(factorial(2), 2)
        self.assertEqual(factorial(3), 6)
        self.assertEqual(factorial(4), 24)
        self.assertEqual(factorial(5), 120)
        self.assertEqual(factorial(-1), -1)

    def test05_add_nums_array(self):
        self.assertEqual(add_nums_array([1, 2, 3]), 6)
        self.assertEqual(add_nums_array([-1, 1]), 0)
        self.assertEqual(add_nums_array([0, 0, 0]), 0)
        self.assertEqual(add_nums_array([100, 200, -300]), 0)
        self.assertEqual(add_nums_array([-1, -2, -3]), -6)
        self.assertEqual(add_nums_array([]), "error")
    
    def test06_first_element(self):
        self.assertEqual(first_element([1, 2, 3]), 1)
        self.assertEqual(first_element([-1, 1]), -1)
        self.assertEqual(first_element([0, 0, 0]), 0)
        self.assertEqual(first_element([100, 200, -300]), 100)
        self.assertEqual(first_element([-1, -2, -3]), -1)
        self.assertEqual(first_element([]), None)

    def test07_last_element(self):
        self.assertEqual(last_element([1, 2, 3]), 3)
        self.assertEqual(last_element([-1, 1]), 1)
        self.assertEqual(last_element([0, 0, 0]), 0)
        self.assertEqual(last_element([100, 200, -300]), -300)
        self.assertEqual(last_element([-1, -2, -3]), -3)
        self.assertEqual(last_element([]), None)

    def test08_num_elements(self):
        self.assertEqual(num_elements([1, 2, 3]), 3)
        self.assertEqual(num_elements([-1, 1]), 2)
        self.assertEqual(num_elements([0, 0, 0]), 3)
        self.assertEqual(num_elements([100, 200, -300]), 3)
        self.assertEqual(num_elements([-1, -2, -3]), 3)
        self.assertEqual(num_elements([]), 0)

    def test09_concat_strings(self):
        self.assertEqual(concat_strings("hello", "world"), "helloworld")
        self.assertEqual(concat_strings("", ""), "")
        self.assertEqual(concat_strings("hello", ""), "hello")
        self.assertEqual(concat_strings("", "world"), "world")

    def test10_num_chars(self):
        self.assertEqual(num_chars("hello"), 5)
        self.assertEqual(num_chars(""), 0)
        self.assertEqual(num_chars("a"), 1)
        self.assertEqual(num_chars("hello world"), 11)

    def test11_capitalize_first_letter(self):
        self.assertEqual(capitalize_first_letter("hello"), "Hello")
        self.assertEqual(capitalize_first_letter(""), "")
        self.assertEqual(capitalize_first_letter("a"), "A")
        self.assertEqual(capitalize_first_letter("hello world"), "Hello world")

    def test12_round_decimal(self):
        self.assertEqual(round_decimal(1.2), 1)
        self.assertEqual(round_decimal(1.5), 2)
        self.assertEqual(round_decimal(2.7), 3)
        self.assertEqual(round_decimal(3.5), 4)

# if __name__ == "__main__":
#     unittest.main()
        
unittest.main(argv=[''], verbosity=2, exit=False)

# %%
# task tests DO NOT MODIFY
import unittest

class Task1_test(unittest.TestCase):
    def test13_add_even_nums(self):
        self.assertEqual(add_even_nums([1, 2, 3, 4]), 6)
        self.assertEqual(add_even_nums([-1, -2, -3, -4]), -6)
        self.assertEqual(add_even_nums([0, 0, 0]), 0)
        self.assertEqual(add_even_nums([]), 0)

    def test14_add_odd_nums(self):
        self.assertEqual(add_odd_nums([1, 2, 3, 4]), 4)
        self.assertEqual(add_odd_nums([-1, -2, -3, -4]), -4)
        self.assertEqual(add_odd_nums([0, 0, 0]), 0)
        self.assertEqual(add_odd_nums([]), 0)

    def test15_reverse_string(self):
        self.assertEqual(reverse_string("hello"), "olleh")
        self.assertEqual(reverse_string(""), "")
        self.assertEqual(reverse_string("a"), "a")
        self.assertEqual(reverse_string("hello world"), "dlrow olleh")

    def test16_is_palindrome(self):
        self.assertTrue(is_palindrome("racecar"))
        self.assertFalse(is_palindrome("hello"))
        self.assertTrue(is_palindrome(""))
        self.assertTrue(is_palindrome("a"))
        self.assertTrue(is_palindrome("bakeryyrekab"))
        self.assertFalse(is_palindrome("hello world"))


unittest.main(argv=[''], verbosity=2, exit=False)
